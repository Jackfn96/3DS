# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle

# # Export pipeline as pickle file
# with open("pipeline.pkl", "wb") as file:
#     pickle.dump(pipe_tuned, file)

# Load pipeline from pickle file
my_pipeline = pickle.load(open("tuned_pipeline_knn.pkl","rb"))

my_pipeline
# Out:
# Pipeline(steps=[('transformers',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   ['one_min_RR_avg']),
#                                                  ('robustscaler',
#                                                   RobustScaler(),
#                                                   ['Heart_Rate'])])),
#                 ('model_knn', KNeighborsClassifier(n_neighbors=3))])

# %%
from DDDS.hrv import HRV
hrv = HRV()
# Out:
# Connected successfully!

# %%
dataframes = hrv.get_dataframes()
# Out:
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
df = dataframes['17_11_2021_10_57 e99']
df
# Out:
#              Timestamp_Google        Timestamp_Device          Device_id  \
# 0     2021-11-17 09:58:22.566 2021-11-17 09:58:22.568  F1:4F:D8:DD:6A:C6
# 1     2021-11-17 09:58:22.774 2021-11-17 09:58:22.771  CA:93:07:67:1E:FF
# 2     2021-11-17 09:58:22.807 2021-11-17 09:58:22.818  FD:9E:84:03:87:71
# 3     2021-11-17 09:58:23.293 2021-11-17 09:58:23.286  FD:9E:84:03:87:71
# 4     2021-11-17 09:58:23.498 2021-11-17 09:58:23.505  F1:4F:D8:DD:6A:C6
# ...                       ...                     ...                ...
# 12634 2021-11-17 11:05:03.944 2021-11-17 11:05:03.954  F1:4F:D8:DD:6A:C6
# 12635 2021-11-17 11:05:04.022 2021-11-17 11:05:04.032  FD:9E:84:03:87:71
# 12636 2021-11-17 11:05:04.542 2021-11-17 11:05:04.557  FD:9E:84:03:87:71
# 12637 2021-11-17 11:05:04.945 2021-11-17 11:05:04.963  F1:4F:D8:DD:6A:C6
# 12638 2021-11-17 11:05:05.059 2021-11-17 11:05:05.073  FD:9E:84:03:87:71
#
#        Heart_Rate               RR_rate  Garmin
# ...

# %%
from DDDS.hrv import hrv_prediction



df = hrv_prediction(df)
df
# Out:
# /home/jfrasern/code/Jackfn96/3DS/DDDS/hrv.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   working_df['one_min_RR_avg'] = sum(list_RR) / len(list_RR)
# /home/jfrasern/code/Jackfn96/3DS/DDDS/hrv.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   last_df = last_df.append(working_df)
# /home/jfrasern/code/Jackfn96/3DS/DDDS/hrv.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
X = df[['Heart_Rate','one_min_RR_avg']]

preds = my_pipeline.predict(X)

# %%
X
# Out:
#        Heart_Rate  one_min_RR_avg
# 0              62      875.126761
# 1              68      875.126761
# 2              66      875.126761
# 3              66      875.126761
# 4              62      875.126761
# ...           ...             ...
# 12595          58      971.682540
# 12596          62      971.682540
# 12597          58      971.682540
# 12598          58      971.682540
# 12599          62      971.682540
#
# [12600 rows x 2 columns]

# %%
pd.Series(preds).unique()
# Out:
# array([1])
