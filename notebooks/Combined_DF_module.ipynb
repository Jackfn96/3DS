# %%
# %load_ext autoreload
# %autoreload 2

# %%
from DDDS.combined_df import CombinedDFs

# %%
combined_dfs = CombinedDFs().combined_dfs
# Out:
# -- Loading annotations --
# Connected successfully!
# Searching sync files... |██████████████████████████████████████████████████| 100.0% Completed
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Done!
# -- Loading HRV --
# Connected successfully!
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# -- DONE --

# %%
df = combined_dfs[0]

# %%
df
# Out:
#                                  Device_id  Heart_Rate     RR_rate  Garmin  \
# Timestamp_Google
# 2021-10-28 07:25:39.949  E3:C6:1E:14:37:C8        90.0          []     1.0
# 2021-10-28 07:25:39.981  E3:C6:1E:14:37:C8        90.0          []     1.0
# 2021-10-28 07:25:40.231  CB:42:7F:0A:7E:0C        84.0      [1276]     1.0
# 2021-10-28 07:25:40.262  E8:AC:14:80:83:29        92.0       [688]     1.0
# 2021-10-28 07:25:40.434  E3:C6:1E:14:37:C8        90.0          []     1.0
# ...                                    ...         ...         ...     ...
# 2021-10-28 08:38:46.142  E3:C6:1E:14:37:C8        88.0       [573]     1.0
# 2021-10-28 08:38:46.174  E3:C6:1E:14:37:C8        88.0          []     1.0
# 2021-10-28 08:38:46.502  CB:42:7F:0A:7E:0C        98.0  [841, 665]     1.0
# 2021-10-28 08:38:46.689  E3:C6:1E:14:37:C8         0.0          []     1.0
# 2021-10-28 08:38:46.736  E3:C6:1E:14:37:C8         0.0          []     1.0
#
# ...
