# %%
# %load_ext autoreload
# %autoreload 2

# %%
from DDDS.combined_df import CombinedDFs

# %%
combined_dfs = CombinedDFs().combined_dfs
# Out:
# -- Loading annotations --
# Connected successfully!
# Searching sync files... |██████████████████████████████████████████████████| 100.0% Completed
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Done!
# -- Loading HRV --
# Connected successfully!
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# -- Combining dataframes --
# -- DONE --

# %%
combined_dfs.combined_dfs[0].iloc[2150:2200]
# Out:
#             Timestamp_Google          Device_id  Heart_Rate     RR_rate  \
# 2150 2021-10-28 07:31:36.948  E3:C6:1E:14:37:C8        87.0       [688]
# 2151 2021-10-28 07:31:36.995  E3:C6:1E:14:37:C8        87.0          []
# 2152 2021-10-28 07:31:37.471  E3:C6:1E:14:37:C8        87.0          []
# 2153 2021-10-28 07:31:37.471  CB:42:7F:0A:7E:0C        89.0       [696]
# 2154 2021-10-28 07:31:37.517  E3:C6:1E:14:37:C8        87.0          []
# 2155 2021-10-28 07:31:37.549  E8:AC:14:80:83:29        87.0       [692]
# 2156 2021-10-28 07:31:37.908  E3:C6:1E:14:37:C8        87.0          []
# 2157 2021-10-28 07:31:37.955  E3:C6:1E:14:37:C8        87.0          []
# 2158 2021-10-28 07:31:38.392  E3:C6:1E:14:37:C8        87.0          []
# 2159 2021-10-28 07:31:38.424  E3:C6:1E:14:37:C8        87.0          []
# 2160 2021-10-28 07:31:38.470  CB:42:7F:0A:7E:0C        89.0  [687, 661]
# 2161 2021-10-28 07:31:38.549  E8:AC:14:80:83:29        87.0  [688, 692]
# ...
